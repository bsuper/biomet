# %%
# %matplotlib inline
import sys
sys.path.append('../')
import exp
import regression as r
import numpy as np

import matplotlib
# %config InlineBackend.figure_format = 'retina'
matplotlib.rcParams['figure.figsize'] = (20.0, 20.0)

# %%
df = exp.get_wp_energy_data()
df.head()
# Out:
#     PET       VPD   air_temp  doy  precip  soil_temp    sw_in  wind_speed  \
# 0  7.33  0.808731  19.179167  195     0.0  22.320833  30.3156    4.958333
# 1  6.52  0.755945  19.325000  196     0.0  21.770833  29.6316    3.791667
# 2  6.92  0.858993  20.262500  197     0.0  21.908333  29.3472    4.137500
# 3  6.35  0.477617  16.791667  198     0.0  22.420833  28.8180    6.033333
# 4  5.13  0.556820  17.016667  199     0.0  21.529167  23.1732    4.350000
#
#    year    wp_RNET    ...       wp_bnd3   wp_bnd7    wp_evi  wp_lswi2  \
# 0  2012  20.798342    ...      0.034186  0.145936  0.355407  0.286584
# 1  2012  20.573593    ...      0.032614  0.138714  0.362843  0.317110
# 2  2012  20.475931    ...      0.031043  0.131493  0.370279  0.347637
# 3  2012  20.571045    ...      0.029471  0.124271  0.377714  0.378163
# 4  2012  16.757401    ...      0.027900  0.117050  0.385150  0.408689
#
#     wp_ndvi  wp_LST.day  wp_LST.night   LW_IN.wp   LW_IN.si      LW_IN
# 0  0.611743   31.567899     17.204530  29.105844  24.562860  29.105844
# 1  0.624457   29.570000     17.390000  29.760736  26.096551  29.760736
# 2  0.637171   31.097908     17.235624  30.299442  25.986418  30.299442
# 3  0.649886   30.868718     17.248525  28.978868  25.122209  28.978868
# 4  0.662600   30.657792     17.259663  30.653667  27.830367  30.653667
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1028 entries, 0 to 1027
# Data columns (total 28 columns):
# PET             1028 non-null float64
# VPD             1028 non-null float64
# air_temp        1028 non-null float64
# doy             1028 non-null int64
# precip          1028 non-null float64
# soil_temp       1028 non-null float64
# sw_in           1028 non-null float64
# wind_speed      1028 non-null float64
# year            1028 non-null int64
# wp_RNET         1028 non-null float64
# wp_ch4_gf       1028 non-null float64
# wp_co2_gf       1028 non-null float64
# wp_er           1028 non-null float64
# wp_gpp          1028 non-null float64
# wp_h            1028 non-null float64
# wp_le           1028 non-null float64
# wp_bnd1         1028 non-null float64
# wp_bnd2         1028 non-null float64
# wp_bnd3         1028 non-null float64
# wp_bnd7         1028 non-null float64
# wp_evi          1028 non-null float64
# wp_lswi2        1028 non-null float64
# wp_ndvi         1028 non-null float64
# wp_LST.day      1028 non-null float64
# wp_LST.night    1028 non-null float64
# LW_IN.wp        1028 non-null float64
# LW_IN.si        1028 non-null float64
# LW_IN           1028 non-null float64
# dtypes: float64(26), int64(2)
# memory usage: 232.9 KB

# %%
X_cols = ["precip", "sw_in", "LW_IN.wp", "VPD", "air_temp", "PET", "wind_speed",
                  "wp_LST.day", "wp_LST.night", "wp_evi", "wp_ndvi", "wp_lswi2"]
Y_cols = ["wp_gpp"]
X, Y = exp.featurize(df, X_cols, Y_cols)
X_train, X_test, Y_train, Y_test = r.get_train_test_split(X, Y, test_size=0.33)
print X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# (688, 12) (688,) (340, 12) (340,)

# %%
Y_pred = r.predict(r.random_forests(), X_train, Y_train, X_test, Y_test)
r.plot_true_vs_pred(Y_test, Y_pred)
# Out:
# R2-score:  0.976291926624
# Mean Squared Error:  28.1349046005
# Median Absolute Error:  2.47402462859
# Explained Variance Error:  0.976332220244
# a: 0.964372606539 b: -1.44755321669

# %%
Y_pred = r.predict(r.xgb_trees(), X_train, Y_train, X_test, Y_test)
r.plot_true_vs_pred(Y_test, Y_pred)
# Out:
# R2-score:  0.974313274563
# Mean Squared Error:  30.4830155621
# Median Absolute Error:  2.6622919948
# Explained Variance Error:  0.974314296712
# a: 0.98040517033 b: -0.710704873096

# %%
Y_pred = r.predict(r.svm(gamma=.1), X_train, Y_train, X_test, Y_test)
r.plot_true_vs_pred(Y_test, Y_pred)
# Out:
# R2-score:  0.850936171238
# Mean Squared Error:  176.897402634
# Median Absolute Error:  6.06648702332
# Explained Variance Error:  0.852767690249
# a: 0.772198638007 b: -6.38318018477

# %%
Y_pred = r.predict(r.dnn(nn_steps=5000), X_train, Y_train, X_test, Y_test)
r.plot_true_vs_pred(Y_test, Y_pred)
# Out:
# Step #100, epoch #14, avg. train loss: 455.51575
# Step #200, epoch #28, avg. train loss: 100.59210
# Step #300, epoch #42, avg. train loss: 35.40783
# Step #400, epoch #57, avg. train loss: 19.61702
# Step #500, epoch #71, avg. train loss: 14.51042
# Step #600, epoch #85, avg. train loss: 10.78028
# Step #700, epoch #100, avg. train loss: 8.69137
# Step #800, epoch #114, avg. train loss: 7.25660
# Step #900, epoch #128, avg. train loss: 6.26101
# Step #1000, epoch #142, avg. train loss: 5.42653
# Step #1100, epoch #157, avg. train loss: 4.84299
# Step #1200, epoch #171, avg. train loss: 4.41801
# Step #1300, epoch #185, avg. train loss: 4.04006
# Step #1400, epoch #200, avg. train loss: 3.75098
# Step #1500, epoch #214, avg. train loss: 3.47730
# Step #1600, epoch #228, avg. train loss: 3.22590
# Step #1700, epoch #242, avg. train loss: 3.02551
# Step #1800, epoch #257, avg. train loss: 2.87069
# Step #1900, epoch #271, avg. train loss: 2.76193
# Step #2000, epoch #285, avg. train loss: 2.54809
# Step #2100, epoch #300, avg. train loss: 2.43729
# Step #2200, epoch #314, avg. train loss: 2.34569
# Step #2300, epoch #328, avg. train loss: 2.24565
# Step #2400, epoch #342, avg. train loss: 2.14454
# Step #2500, epoch #357, avg. train loss: 2.05971
# Step #2600, epoch #371, avg. train loss: 2.00106
# Step #2700, epoch #385, avg. train loss: 1.90119
# Step #2800, epoch #400, avg. train loss: 1.83462
# Step #2900, epoch #414, avg. train loss: 1.75464
# Step #3000, epoch #428, avg. train loss: 1.70579
# Step #3100, epoch #442, avg. train loss: 1.63475
# Step #3200, epoch #457, avg. train loss: 1.57058
# Step #3300, epoch #471, avg. train loss: 1.53929
# Step #3400, epoch #485, avg. train loss: 1.46357
# Step #3500, epoch #500, avg. train loss: 1.42497
# Step #3600, epoch #514, avg. train loss: 1.38612
# Step #3700, epoch #528, avg. train loss: 1.33673
# Step #3800, epoch #542, avg. train loss: 1.31825
# Step #3900, epoch #557, avg. train loss: 1.26400
# Step #4000, epoch #571, avg. train loss: 1.23728
# Step #4100, epoch #585, avg. train loss: 1.21204
# Step #4200, epoch #600, avg. train loss: 1.15542
# Step #4300, epoch #614, avg. train loss: 1.12697
# Step #4400, epoch #628, avg. train loss: 1.11507
# Step #4500, epoch #642, avg. train loss: 1.08527
# Step #4600, epoch #657, avg. train loss: 1.05876
# Step #4700, epoch #671, avg. train loss: 1.03209
# Step #4800, epoch #685, avg. train loss: 1.02040
# Step #4900, epoch #700, avg. train loss: 0.99100
# Step #5000, epoch #714, avg. train loss: 0.96227
# R2-score:  0.969488059428
# Mean Squared Error:  36.2092070312
# Median Absolute Error:  2.42244564444
# Explained Variance Error:  0.969508766905
# a: [ 1.00521404] b: [ 0.02308477]
